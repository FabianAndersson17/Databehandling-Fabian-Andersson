# %% [markdown]
# # High performance
#
# ```python
# mask = (x > 0.5) & (y < 0.5)
# ```
#
# ex:
# df = dff[df[mask]]
#
# ```python
# tmp1 = (x > 0.5)
# tmp2 = (y < 0.5)
# mask = tmp1 & tmp2
# ```
#
# Can use pd.eval("") -> performs elementwise directly using numexpr
#
# Good for compound expressions

# %%
import numpy as np
import pandas as pd

nrows, ncols = 1000000, 100
df1, df2, df3, df4 = [pd.DataFrame(np.random.randn(nrows, ncols)) for _ in range(4)]
df1.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -1.413877  1.196057  0.558456  1.904732  1.060966 -1.247035 -1.912800
# 1 -0.207292  2.066073  0.922457  0.063423  0.777674 -0.317366  2.098534
# 2 -0.852549 -0.011128 -2.559354 -2.105246  0.659456 -0.114802  0.349166
# 3 -0.496710  0.972605  0.446056 -0.918706 -0.346973 -1.024539 -0.023737
# 4  0.544510 -0.292143  0.068029  0.668903  0.756693 -0.331481  0.277662
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.494966 -0.807773 -0.506227  ... -1.173020 -0.558082 -0.080112  0.575089
# 1  0.169719  0.123358  1.827096  ... -1.355595  0.281215 -0.486158 -1.110272
# 2 -0.705398  0.515848 -0.547832  ... -0.784568  0.318347  0.118804 -0.836228
# 3 -1.327531 -0.027886  0.302788  ... -2.085853  1.438647 -0.281029 -0.655393
# 4  0.124358 -0.476210 -1.438507  ... -0.965087 -0.271741 -1.793447 -0.738675
#
#          94        95        96        97        98        99
# 0 -1.670474  0.890756 -0.588846  1.605141 -1.247288  0.115607
# 1  1.072051  0.807680  0.152930  1.581510 -0.528713  0.786837
# 2  0.475111 -0.498715  0.598740 -1.410780 -0.227739  0.309349
# 3 -0.085709  0.821655  0.172188  0.905978 -0.506872 -1.885563
# 4  2.726956  0.323555 -0.919744 -0.570010 -1.065592 -0.361480
#
# [5 rows x 100 columns]

# %%
# %timeit df1 + df2 + df3 + df4
# Out:
# 1.24 s ± 27.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit pd.eval("df1 + df2 + df3 + df4")
# Out:
# 572 ms ± 25.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
plain = df1 + df2 + df3 + df4
sum_eval = pd.eval("df1 + df2 + df3 + df4")
# Out:
# True

# %%
#df.eval()
rolls = pd.DataFrame(np.random.randint(1,6, (6,3)), columns=["Die1", "Die2", "Die3"])
rolls.eval("Sum = Die1 + Die2 + Die3", inplace = True)
rolls
# Out:
#    Die1  Die2  Die3  Sum
# 0     5     1     5   11
# 1     4     3     1    8
# 2     5     1     2    8
# 3     4     1     5   10
# 4     3     2     4    9
# 5     4     2     2    8

# %%
# use variables

high = 10 
rolls.eval("Winner = Sum > @high", inplace = True)
rolls
# Out:
#    Die1  Die2  Die3  Sum  Winner
# 0     5     1     5   11    True
# 1     4     3     1    8   False
# 2     5     1     2    8   False
# 3     4     1     5   10   False
# 4     3     2     4    9   False
# 5     4     2     2    8   False

# %%
rolls[rolls["Sum"] <= high]
# Out:
#    Die1  Die2  Die3  Sum  Winner
# 1     4     3     1    8   False
# 2     5     1     2    8   False
# 3     4     1     5   10   False
# 4     3     2     4    9   False
# 5     4     2     2    8   False

# %% [markdown]
# # Query

# %%
rolls.query("Sum <= @high")
# Out:
#    Die1  Die2  Die3  Sum  Winner
# 1     4     3     1    8   False
# 2     5     1     2    8   False
# 3     4     1     5   10   False
# 4     3     2     4    9   False
# 5     4     2     2    8   False

# %%
os =pd.read_csv("Data/athlete_events.csv")
os
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal
# 0          Basketball               Basketball Men's Basketball   NaN
# 1                Judo              Judo Men's Extra-Lightweight   NaN
# 2            Football                   Football Men's Football   NaN
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres   NaN
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles   NaN
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual   NaN
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team   NaN
# 271114      Bobsleigh                      Bobsleigh Men's Four   NaN
# 271115      Bobsleigh                      Bobsleigh Men's Four   NaN
#
# [271116 rows x 15 columns]

# %%
# %timeit os[os["NOC"] == "SWE"]
# %timeit os.query("NOC == 'SWE'")
# Out:
# 21.2 ms ± 261 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 12.6 ms ± 56.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit os[os["Height"] > 180]
# %timeit os.query("Height > 180")
# Out:
# 14.6 ms ± 180 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 17.6 ms ± 216 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit os[(os["Sex"] == "F") & (os["Height"] > 180) & os["NOC"] == "SWE"]
# %timeit os.query("Sex == 'F' & Height > 180 & NOC == 'SWE'")
# Out:
# 36.6 ms ± 4.22 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 17.1 ms ± 951 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
os.query("Sex == 'F' & Height > 180 & NOC == 'SWE'")
# Out:
#             ID                              Name Sex   Age  Height  Weight  \
# 729        417                  Sara Helena berg   F  17.0   190.0    73.0
# 5175      2940                         Jenny Alm   F  27.0   184.0    80.0
# 7555      4210  Marina Vladimirovna Andrievskaia   F  29.0   182.0    66.0
# 19070    10088            Anna Therese Bengtsson   F  29.0   187.0    83.0
# 28221    14643              Maria Helene Brandin   F  25.0   186.0    85.0
# ...        ...                               ...  ..   ...     ...     ...
# 242230  121329           Linnea Maria Torstenson   F  33.0   186.0    82.0
# 259242  129789            Anna Karolina Westberg   F  22.0   184.0    78.0
# 259243  129789            Anna Karolina Westberg   F  26.0   184.0    78.0
# 259934  130126              Johanna Maria Wiberg   F  24.0   184.0    78.0
# 259935  130126              Johanna Maria Wiberg   F  28.0   184.0    78.0
#
#           Team  NOC        Games  Year  Season            City      Sport  \
# 729     Sweden  SWE  1988 Summer  1988  Summer           Seoul   Swimming
# 5175    Sweden  SWE  2016 Summer  2016  Summer  Rio de Janeiro   Handball
# 7555    Sweden  SWE  2004 Summer  2004  Summer          Athina  Badminton
# 19070   Sweden  SWE  2008 Summer  2008  Summer         Beijing   Handball
# 28221   Sweden  SWE  1988 Summer  1988  Summer           Seoul     Rowing
# ...        ...  ...          ...   ...     ...             ...        ...
# 242230  Sweden  SWE  2016 Summer  2016  Summer  Rio de Janeiro   Handball
# 259242  Sweden  SWE  2000 Summer  2000  Summer          Sydney   Football
# 259243  Sweden  SWE  2004 Summer  2004  Summer          Athina   Football
# 259934  Sweden  SWE  2008 Summer  2008  Summer         Beijing   Handball
# 259935  Sweden  SWE  2012 Summer  2012  Summer          London   Handball
#
#                                        Event Medal
# 729     Swimming Women's 50 metres Freestyle   NaN
# 5175               Handball Women's Handball   NaN
# 7555               Badminton Women's Singles   NaN
# 19070              Handball Women's Handball   NaN
# 28221           Rowing Women's Double Sculls   NaN
# ...                                      ...   ...
# 242230             Handball Women's Handball   NaN
# 259242             Football Women's Football   NaN
# 259243             Football Women's Football   NaN
# 259934             Handball Women's Handball   NaN
# 259935             Handball Women's Handball   NaN
#
# [95 rows x 15 columns]
